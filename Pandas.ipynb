# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Data Structure in pandas
# series

# %%
l = list(range(0,10,2))

# %%
df1 = pd.Series(l)
df1
# Out:
# 0    0
# 1    2
# 2    4
# 3    6
# 4    8
# dtype: int64

# %%
df2 = pd.DataFrame(l,columns = ['values'])
df2
# Out:
#    values
# 0       0
# 1       2
# 2       4
# 3       6
# 4       8

# %%
df2.columns
# Out:
# Index(['values'], dtype='str')

# %%
df2.head()
# Out:
#    values
# 0       0
# 1       2
# 2       4
# 3       6
# 4       8

# %%
df2.head(2)
# Out:
#    values
# 0       0
# 1       2

# %%
df2.tail()
# Out:
#    values
# 0       0
# 1       2
# 2       4
# 3       6
# 4       8

# %%
df2.tail(2)
# Out:
#    values
# 3       6
# 4       8

# %%
df2.info
# Out:
# <bound method DataFrame.info of    values
# 0       0
# 1       2
# 2       4
# 3       6
# 4       8>

# %%
df2.describe()
# Out:
#          values
# count  5.000000
# mean   4.000000
# std    3.162278
# min    0.000000
# 25%    2.000000
# 50%    4.000000
# 75%    6.000000
# max    8.000000

# %%
df2.size
# Out:
# 5

# %%
data = {
    'prompts':['explain AI','Write_code','Summerize'],
    'token':[150,300,280],
    'model':['GPT-4','GPT-4','Cloud']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       prompts  token  model
# 0  explain AI    150  GPT-4
# 1  Write_code    300  GPT-4
# 2   Summerize    280  Cloud

# %%
df.head(2)
# Out:
#       prompts  token  model
# 0  explain AI    150  GPT-4
# 1  Write_code    300  GPT-4

# %%
df.tail(1)
# Out:
#      prompts  token  model
# 2  Summerize    280  Cloud

# %%
df.describe()
# Out:
#             token
# count    3.000000
# mean   243.333333
# std     81.445278
# min    150.000000
# 25%    215.000000
# 50%    280.000000
# 75%    290.000000
# max    300.000000

# %%
# !pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
df1 = pd.read_excel('/Users/sanjaymagar/Desktop/Ecommerce Sales Analysis.xlsx')

# %%
df1.head(2)
# Out:
#    Row ID        Order ID  Year Order Date  Ship Date     Ship Mode  \
# 0       1  CA-2013-152156  2013 2013-11-09 2013-11-12  Second Class
# 1       2  CA-2013-152156  2013 2013-11-09 2013-11-12  Second Class
#
#   Customer ID Customer Name   Segment        Country  ... Postal Code Region  \
# 0    CG-12520   Claire Gute  Consumer  United States  ...       42420  South
# 1    CG-12520   Claire Gute  Consumer  United States  ...       42420  South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 22 columns]

# %%
df.to_csv('llm usage.csv',index=False)

# %%
load = pd.read_csv('llm usage.csv')
load
# Out:
#       prompts  token  model
# 0  explain AI    150  GPT-4
# 1  Write_code    300  GPT-4
# 2   Summerize    280  Cloud

# %% [markdown]
# # get  data set from kagle

# %%
data_k = pd.read_csv(r'/Users/sanjaymagar/Desktop/Cleaned_HR_Data_Analysis.csv')
data_k.head(2)
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
# 1         3428  11-Feb-23  Production Technician I           EW
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
# 1         Active     Contract  Zone A                  Part-Time
#
#       DepartmentType              Division  ... Engagement Score  \
# 0  Production         Finance & Accounting  ...                1
# 1  Production                       Aerial  ...                2
#
#   Satisfaction Score Work-Life Balance Score Training Date  \
# 0                  2                       3     15-Jul-23
# 1                  1                       5     12-Sep-22
#
#     Training Program Name Training Type  Training Outcome  \
# 0  Leadership Development      Internal            Failed
# 1        Customer Service      External        Incomplete
#
# ...

# %%
data_k.columns
# Out:
# Index(['Employee ID', 'StartDate', 'Title', 'BusinessUnit', 'EmployeeStatus',
#        'EmployeeType', 'PayZone', 'EmployeeClassificationType',
#        'DepartmentType', 'Division', 'DOB', 'State', 'GenderCode', 'RaceDesc',
#        'MaritalDesc', 'Performance Score', 'Current Employee Rating',
#        'Survey Date', 'Engagement Score', 'Satisfaction Score',
#        'Work-Life Balance Score', 'Training Date', 'Training Program Name',
#        'Training Type', 'Training Outcome', 'Training Duration(Days)',
#        'Training Cost', 'Age'],
#       dtype='str')

# %%
data_k.describe()
# Out:
#        Employee ID  Current Employee Rating  Engagement Score  \
# count  2845.000000              2845.000000       2845.000000
# mean   2470.591916                 2.974692          2.941652
# std     859.450107                 1.012610          1.435230
# min    1001.000000                 1.000000          1.000000
# 25%    1736.000000                 2.000000          2.000000
# 50%    2456.000000                 3.000000          3.000000
# 75%    3197.000000                 3.000000          4.000000
# max    4000.000000                 5.000000          5.000000
#
#        Satisfaction Score  Work-Life Balance Score  Training Duration(Days)  \
# count         2845.000000              2845.000000              2845.000000
# mean             3.028471                 2.989104                 2.973989
# std              1.410067                 1.408816                 1.419682
# min              1.000000                 1.000000                 1.000000
# ...

# %%
data_k.isna().sum()
# Out:
# Employee ID                   0
# StartDate                     0
# Title                         0
# BusinessUnit                  0
# EmployeeStatus                0
# EmployeeType                  0
# PayZone                       0
# EmployeeClassificationType    0
# DepartmentType                0
# Division                      0
# DOB                           0
# State                         0
# GenderCode                    0
# RaceDesc                      0
# MaritalDesc                   0
# Performance Score             0
# Current Employee Rating       0
# Survey Date                   0
# Engagement Score              0
# Satisfaction Score            0
# Work-Life Balance Score       0
# Training Date                 0
# Training Program Name         0
# Training Type                 0
# Training Outcome              0
# Training Duration(Days)       0
# Training Cost                 0
# Age                           0
# dtype: int64

# %%
data_k.tail(2)
# Out:
#       Employee ID  StartDate                    Title BusinessUnit  \
# 2843         3425  28-May-19  Production Technician I          WBL
# 2844         3426  27-Apr-22  Production Technician I          BPC
#
#      EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 2843     Terminated     Contract  Zone B                  Full-Time
# 2844         Active    Full-Time  Zone B                  Temporary
#
#          DepartmentType          Division  ... Engagement Score  \
# 2843  Production                   Aerial  ...                5
# 2844  Production         Field Operations  ...                1
#
#      Satisfaction Score Work-Life Balance Score Training Date  \
# 2843                  2                       3     19-May-23
# 2844                  3                       2     02-May-23
#
#        Training Program Name Training Type  Training Outcome  \
# 2843        Technical Skills      External         Completed
# ...

# %%
data_k['Engagement Score']
# Out:
# 0       1
# 1       2
# 2       1
# 3       5
# 4       2
#        ..
# 2840    5
# 2841    4
# 2842    2
# 2843    5
# 2844    1
# Name: Engagement Score, Length: 2845, dtype: int64

# %%
cond1 = data_k['Engagement Score']<5
cond2 = data_k['Age']>50

# %%
data_k['Age']
# Out:
# 0       50
# 1       58
# 2       27
# 3       23
# 4       50
#         ..
# 2840    63
# 2841    19
# 2842    23
# 2843    65
# 2844    32
# Name: Age, Length: 2845, dtype: int64

# %%
#And condition 
data_a  = data_k[cond1 & cond2]
data_a.head(5)
# Out:
#     Employee ID  StartDate                    Title BusinessUnit  \
# 1          3428  11-Feb-23  Production Technician I           EW
# 5          3432  17-Jan-20       Area Sales Manager          BPC
# 6          3433  06-Apr-22       Area Sales Manager          WBL
# 7          3434  06-Nov-20       Area Sales Manager         CCDR
# 10         3437  04-Aug-23       Area Sales Manager          SVG
#
#    EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 1          Active     Contract  Zone A                  Part-Time
# 5          Active     Contract  Zone B                  Full-Time
# 6          Active    Full-Time  Zone B                  Temporary
# 7          Active     Contract  Zone C                  Full-Time
# 10         Active     Contract  Zone B                  Temporary
#
#        DepartmentType          Division  ... Engagement Score  \
# 1   Production                   Aerial  ...                2
# ...

# %%
# Or condition 
data_o = data_k[cond1 | cond2]
data_o.head(5)
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
# 1         3428  11-Feb-23  Production Technician I           EW
# 2         3429  10-Dec-18       Area Sales Manager           PL
# 4         3431  29-Jun-19       Area Sales Manager          TNS
# 5         3432  17-Jan-20       Area Sales Manager          BPC
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
# 1         Active     Contract  Zone A                  Part-Time
# 2         Active    Full-Time  Zone B                  Part-Time
# 4         Active     Contract  Zone A                  Temporary
# 5         Active     Contract  Zone B                  Full-Time
#
#       DepartmentType              Division  ... Engagement Score  \
# 0  Production         Finance & Accounting  ...                1
# ...

# %%
# isin 
data_k['EmployeeClassificationType'].unique()
# Out:
# <StringArray>
# ['Temporary', 'Part-Time', 'Full-Time']
# Length: 3, dtype: str

# %%
con = ['Temporary', 'Part-Time']

# %%
data_k[data_k['EmployeeClassificationType'].isin(con)].head(5)
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
# 1         3428  11-Feb-23  Production Technician I           EW
# 2         3429  10-Dec-18       Area Sales Manager           PL
# 4         3431  29-Jun-19       Area Sales Manager          TNS
# 6         3433  06-Apr-22       Area Sales Manager          WBL
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
# 1         Active     Contract  Zone A                  Part-Time
# 2         Active    Full-Time  Zone B                  Part-Time
# 4         Active     Contract  Zone A                  Temporary
# 6         Active    Full-Time  Zone B                  Temporary
#
#       DepartmentType              Division  ... Engagement Score  \
# 0  Production         Finance & Accounting  ...                1
# ...

# %%
# not is in 
data_k[~data_k['EmployeeClassificationType'].isin(con)].head(5)
# Out:
#     Employee ID  StartDate               Title BusinessUnit EmployeeStatus  \
# 3          3430  21-Jun-21  Area Sales Manager         CCDR         Active
# 5          3432  17-Jan-20  Area Sales Manager          BPC         Active
# 7          3434  06-Nov-20  Area Sales Manager         CCDR         Active
# 13         3440  05-Dec-19  Area Sales Manager         CCDR         Active
# 15         3442  09-Jul-19  Area Sales Manager          PYZ         Active
#
#    EmployeeType PayZone EmployeeClassificationType DepartmentType  \
# 3      Contract  Zone A                  Full-Time          Sales
# 5      Contract  Zone B                  Full-Time          Sales
# 7      Contract  Zone C                  Full-Time          Sales
# 13     Contract  Zone A                  Full-Time          Sales
# 15    Full-Time  Zone A                  Full-Time          IT/IS
#
#                 Division  ... Engagement Score Satisfaction Score  \
# ...

# %%
data_k.loc[1:10,['Employee ID','Title']]
# Out:
#     Employee ID                    Title
# 1          3428  Production Technician I
# 2          3429       Area Sales Manager
# 3          3430       Area Sales Manager
# 4          3431       Area Sales Manager
# 5          3432       Area Sales Manager
# 6          3433       Area Sales Manager
# 7          3434       Area Sales Manager
# 8          3435       Area Sales Manager
# 9          3436       Area Sales Manager
# 10         3437       Area Sales Manager

# %%
data_k.iloc[0:5,3:5]
# Out:
#   BusinessUnit EmployeeStatus
# 0         CCDR         Active
# 1           EW         Active
# 2           PL         Active
# 3         CCDR         Active
# 4          TNS         Active

# %%
sdata = data_k['Satisfaction Score']
sdata.head()
# Out:
# 0    2
# 1    1
# 2    2
# 3    5
# 4    5
# Name: Satisfaction Score, dtype: int64

# %%
sdata.value_counts()
# Out:
# Satisfaction Score
# 4    612
# 3    569
# 5    565
# 1    562
# 2    537
# Name: count, dtype: int64

# %%
sdata.unique()
# Out:
# array([2, 1, 5, 3, 4])

# %%
sdata.nunique()
# Out:
# 5

# %%
sdata.mean()
# Out:
# np.float64(3.0284710017574694)

# %%
sdata.median()
# Out:
# np.float64(3.0)

# %%
sdata.sort_values()
# Out:
# 1379    1
# 478     1
# 2316    1
# 2315    1
# 1776    1
#        ..
# 2099    5
# 2101    5
# 688     5
# 2106    5
# 1422    5
# Name: Satisfaction Score, Length: 2845, dtype: int64

# %%
sdata.quantile(0.5)
# Out:
# np.float64(3.0)

# %%
sdata.quantile(0.75)
# Out:
# np.float64(4.0)

# %%
sdata.quantile(0.25)
# Out:
# np.float64(2.0)

# %%
data_k.sort_values(by=['Age'])
# Out:
#       Employee ID  StartDate                     Title BusinessUnit  \
# 1518         2038  02-Sep-18   Production Technician I          MSC
# 1228         1743  30-Nov-18   Production Technician I          SVG
# 2622         3176  13-Dec-18   Production Technician I          SVG
# 2260         2786  29-Dec-18  Production Technician II          PYZ
# 636          1127  26-Feb-19  Production Technician II           PL
# ...           ...        ...                       ...          ...
# 1539         2060  26-Jan-23   Production Technician I          BPC
# 974          1474  01-Feb-23  Production Technician II          MSC
# 2755         3326  14-Jan-22   Production Technician I          PYZ
# 1569         2090  12-Jan-23  Production Technician II           EW
# 604          1095  07-Apr-23  Production Technician II          WBL
#
#      EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 1518         Active    Part-Time  Zone A                  Temporary
# ...

# %% [markdown]
# # Data cleaning with pandas

# %%
# rename the column 
data_k.rename(columns = {'Age':'Umer'},inplace = True)
data_k.head(2)
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
# 1         3428  11-Feb-23  Production Technician I           EW
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
# 1         Active     Contract  Zone A                  Part-Time
#
#       DepartmentType              Division  ... Engagement Score  \
# 0  Production         Finance & Accounting  ...                1
# 1  Production                       Aerial  ...                2
#
#   Satisfaction Score Work-Life Balance Score Training Date  \
# 0                  2                       3     15-Jul-23
# 1                  1                       5     12-Sep-22
#
#     Training Program Name Training Type  Training Outcome  \
# 0  Leadership Development      Internal            Failed
# 1        Customer Service      External        Incomplete
#
# ...

# %%
data_k.rename(columns = {'Training Duration(Days)':'Training duration(day)','Training Cost':'training cost'},inplace = True)
data_k.head(2)
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
# 1         3428  11-Feb-23  Production Technician I           EW
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
# 1         Active     Contract  Zone A                  Part-Time
#
#       DepartmentType              Division  ... Engagement Score  \
# 0  Production         Finance & Accounting  ...                1
# 1  Production                       Aerial  ...                2
#
#   Satisfaction Score Work-Life Balance Score Training Date  \
# 0                  2                       3     15-Jul-23
# 1                  1                       5     12-Sep-22
#
#     Training Program Name Training Type  Training Outcome  \
# 0  Leadership Development      Internal            Failed
# 1        Customer Service      External        Incomplete
#
# ...

# %%
data_k.rename(columns = {'Umer':'Age'},inplace = True)
data_k.head(1)
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
#
#       DepartmentType              Division  ... Engagement Score  \
# 0  Production         Finance & Accounting  ...                1
#
#   Satisfaction Score Work-Life Balance Score Training Date  \
# 0                  2                       3     15-Jul-23
#
#     Training Program Name Training Type  Training Outcome  \
# 0  Leadership Development      Internal            Failed
#
#   Training duration(day)  training cost  Age
# 0                      2         606.11   50
#
# [1 rows x 28 columns]

# %%
#load the unclened data set 
data_u = pd.read_csv(r"/Users/sanjaymagar/Desktop/Messy_HR_Dataset_Detailed.csv")

# %%
df1 = data_u.copy()
df1.head(4)
# Out:
#    Unnamed: 0 FirstName LastName  StartDate ExitDate                    Title  \
# 0           0     Uriah  Bridges  20-Sep-19      NaN  Production Technician I
# 1           1     Paula    Small  11-Feb-23      NaN  Production Technician I
# 2           2    Edward     Buck  10-Dec-18      NaN       Area Sales Manager
# 3           3   Michael  Riordan  21-Jun-21      NaN       Area Sales Manager
#
#         Supervisor                        ADEmail BusinessUnit EmployeeStatus  \
# 0     Peter Oneill    uriah.bridges@bilearner.com         CCDR         Active
# 1  Renee Mccormick      paula.small@bilearner.com           EW         Active
# 2   Crystal Walker      edward.buck@bilearner.com           PL         Active
# 3   Rebekah Wright  michael.riordan@bilearner.com         CCDR         Active
#
#    ... Satisfaction Score Work-Life Balance Score Training Date  \
# 0  ...                  2                       3     15-Jul-23
# ...

# %%
df1.isna().sum()
# Out:
# Unnamed: 0                       0
# FirstName                        0
# LastName                         0
# StartDate                        0
# ExitDate                      1544
# Title                            0
# Supervisor                       0
# ADEmail                          0
# BusinessUnit                     0
# EmployeeStatus                   0
# EmployeeType                     0
# PayZone                          0
# EmployeeClassificationType       0
# TerminationType                  0
# TerminationDescription        1544
# DepartmentType                   0
# Division                         0
# DOB                              0
# State                            0
# JobFunctionDescription           0
# GenderCode                       0
# LocationCode                     0
# RaceDesc                         0
# MaritalDesc                      0
# Performance Score                0
# Current Employee Rating          0
# Employee ID                      0
# ...

# %%
df1.drop('ExitDate',axis =1,inplace = True) # droping the columns

# %%
df1.isna().sum()
# Out:
# Unnamed: 0                       0
# FirstName                        0
# LastName                         0
# StartDate                        0
# Title                            0
# Supervisor                       0
# ADEmail                          0
# BusinessUnit                     0
# EmployeeStatus                   0
# EmployeeType                     0
# PayZone                          0
# EmployeeClassificationType       0
# TerminationType                  0
# TerminationDescription        1544
# DepartmentType                   0
# Division                         0
# DOB                              0
# State                            0
# JobFunctionDescription           0
# GenderCode                       0
# LocationCode                     0
# RaceDesc                         0
# MaritalDesc                      0
# Performance Score                0
# Current Employee Rating          0
# Employee ID                      0
# Survey Date                      0
# ...

# %%
df1['ExitDate'] = data_u['ExitDate']

# %%
df1.isna().sum()
# Out:
# Unnamed: 0                       0
# FirstName                        0
# LastName                         0
# StartDate                        0
# Title                            0
# Supervisor                       0
# ADEmail                          0
# BusinessUnit                     0
# EmployeeStatus                   0
# EmployeeType                     0
# PayZone                          0
# EmployeeClassificationType       0
# TerminationType                  0
# TerminationDescription        1544
# DepartmentType                   0
# Division                         0
# DOB                              0
# State                            0
# JobFunctionDescription           0
# GenderCode                       0
# LocationCode                     0
# RaceDesc                         0
# MaritalDesc                      0
# Performance Score                0
# Current Employee Rating          0
# Employee ID                      0
# Survey Date                      0
# ...

# %%
df1.head(1)
# Out:
#    Unnamed: 0 FirstName LastName  StartDate                    Title  \
# 0           0     Uriah  Bridges  20-Sep-19  Production Technician I
#
#      Supervisor                      ADEmail BusinessUnit EmployeeStatus  \
# 0  Peter Oneill  uriah.bridges@bilearner.com         CCDR         Active
#
#   EmployeeType  ... Work-Life Balance Score Training Date  \
# 0     Contract  ...                       3     15-Jul-23
#
#     Training Program Name Training Type Training Outcome      Location  \
# 0  Leadership Development      Internal           Failed  South Marisa
#
#             Trainer Training Duration(Days) Training Cost ExitDate
# 0  Taylor Rodriguez                       2        606.11      NaN
#
# [1 rows x 39 columns]

# %%
#drop all categorical value 
data_new = df1.select_dtypes(['Int64','Float64']) # slecet only the numeric value 
data_new
# Out:
#       Unnamed: 0  LocationCode  Current Employee Rating  Employee ID  \
# 0              0         34904                        4         3427
# 1              1          6593                        3         3428
# 2              2          2330                        4         3429
# 3              3         58782                        2         3430
# 4              4         33174                        3         3431
# ...          ...           ...                      ...          ...
# 3145         450         81607                        3         3877
# 3146        2164         19215                        4         2591
# 3147        2372         54859                        2         2799
# 3148        2012         52238                        5         2439
# 3149         270         51256                        4         3697
#
#       Engagement Score  Satisfaction Score  Work-Life Balance Score  \
# 0                    1                   2                        3
# ...

# %%
# add columns in data set 
data_new ['new_score of satisfaction'] = data_new['Satisfaction Score']*0.1
data_new
# Out:
#       Unnamed: 0  LocationCode  Current Employee Rating  Employee ID  \
# 0              0         34904                        4         3427
# 1              1          6593                        3         3428
# 2              2          2330                        4         3429
# 3              3         58782                        2         3430
# 4              4         33174                        3         3431
# ...          ...           ...                      ...          ...
# 3145         450         81607                        3         3877
# 3146        2164         19215                        4         2591
# 3147        2372         54859                        2         2799
# 3148        2012         52238                        5         2439
# 3149         270         51256                        4         3697
#
#       Engagement Score  Satisfaction Score  Work-Life Balance Score  \
# 0                    1                   2                        3
# ...

# %%
data_new ['new_score of work-life'] = data_new['Work-Life Balance Score']*0.1 #add new columns to the dataframe 
data_new
# Out:
#       Unnamed: 0  LocationCode  Current Employee Rating  Employee ID  \
# 0              0         34904                        4         3427
# 1              1          6593                        3         3428
# 2              2          2330                        4         3429
# 3              3         58782                        2         3430
# 4              4         33174                        3         3431
# ...          ...           ...                      ...          ...
# 3145         450         81607                        3         3877
# 3146        2164         19215                        4         2591
# 3147        2372         54859                        2         2799
# 3148        2012         52238                        5         2439
# 3149         270         51256                        4         3697
#
#       Engagement Score  Satisfaction Score  Work-Life Balance Score  \
# 0                    1                   2                        3
# ...

# %%
data_new.drop(['new_score of satisfaction','new_score of work-life'],axis = 1, inplace = True ) # drop the columns form the dataset

# %%
data_new
# Out:
#       Unnamed: 0  LocationCode  Current Employee Rating  Employee ID  \
# 0              0         34904                        4         3427
# 1              1          6593                        3         3428
# 2              2          2330                        4         3429
# 3              3         58782                        2         3430
# 4              4         33174                        3         3431
# ...          ...           ...                      ...          ...
# 3145         450         81607                        3         3877
# 3146        2164         19215                        4         2591
# 3147        2372         54859                        2         2799
# 3148        2012         52238                        5         2439
# 3149         270         51256                        4         3697
#
#       Engagement Score  Satisfaction Score  Work-Life Balance Score  \
# 0                    1                   2                        3
# ...

# %%
def ssclass(value):
    if value>=4:
        return 'very good satisfide'
    elif value>=3:
        return 'good satisfide'
    elif value>=2:
        return 'nice satisfide'
    else:
        return 'bad satisfide'
data_new['Satisfaction Score class'] = data_new['Satisfaction Score'].apply(ssclass)

# %%
df1.drop('Satisfaction Score class',axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[413], line 1
# ----> 1 df1.drop('Satisfaction Score class',axis = 1,inplace = True)
#
# File ~/Desktop/python with data science revision /venv/lib/python3.13/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6284                 weight  250.0   150.0
#    6285         falcon  speed   320.0   250.0
#    6286                 weight  1.0     0.8
#    6287         """
# -> 6288         return super().drop(
#    6289             labels=labels,
#    6290             axis=axis,
#    6291             index=index,
#
# File ~/Desktop/python with data science revision /venv/lib/python3.13/site-packages/pandas/core/generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
# ...

# %%
df1.head(2)

# %%
data_new.head()

# %%
df1.isna().sum()
# Out:
# Unnamed: 0                       0
# FirstName                        0
# LastName                         0
# StartDate                        0
# Title                            0
# Supervisor                       0
# ADEmail                          0
# BusinessUnit                     0
# EmployeeStatus                   0
# EmployeeType                     0
# PayZone                          0
# EmployeeClassificationType       0
# TerminationType                  0
# TerminationDescription        1544
# DepartmentType                   0
# Division                         0
# DOB                              0
# State                            0
# JobFunctionDescription           0
# GenderCode                       0
# LocationCode                     0
# RaceDesc                         0
# MaritalDesc                      0
# Performance Score                0
# Current Employee Rating          0
# Employee ID                      0
# Survey Date                      0
# ...

# %%
df1.shape
# Out:
# (3150, 39)

# %%
df1.dropna(subset=['TerminationDescription'],inplace = True) # drop all the missing value by using the dropna method

# %%
df2 = data_u.copy()

# %%
df2.isna().sum()
# Out:
# Unnamed: 0                       0
# FirstName                        0
# LastName                         0
# StartDate                        0
# ExitDate                      1544
# Title                            0
# Supervisor                       0
# ADEmail                          0
# BusinessUnit                     0
# EmployeeStatus                   0
# EmployeeType                     0
# PayZone                          0
# EmployeeClassificationType       0
# TerminationType                  0
# TerminationDescription        1544
# DepartmentType                   0
# Division                         0
# DOB                              0
# State                            0
# JobFunctionDescription           0
# GenderCode                       0
# LocationCode                     0
# RaceDesc                         0
# MaritalDesc                      0
# Performance Score                0
# Current Employee Rating          0
# Employee ID                      0
# ...

# %%
df2.dropna(subset = ['ExitDate'],inplace = True )

# %%
data_u.isna().sum()
df3 = data_u.copy()

# %%
df3.isna().sum()
# Out:
# Unnamed: 0                       0
# FirstName                        0
# LastName                         0
# StartDate                        0
# ExitDate                      1544
# Title                            0
# Supervisor                       0
# ADEmail                          0
# BusinessUnit                     0
# EmployeeStatus                   0
# EmployeeType                     0
# PayZone                          0
# EmployeeClassificationType       0
# TerminationType                  0
# TerminationDescription        1544
# DepartmentType                   0
# Division                         0
# DOB                              0
# State                            0
# JobFunctionDescription           0
# GenderCode                       0
# LocationCode                     0
# RaceDesc                         0
# MaritalDesc                      0
# Performance Score                0
# Current Employee Rating          0
# Employee ID                      0
# ...

# %%
#fill the null value 
#fill by mode,median,mean ect
#fill using method ffill for forward fill 
#fill using method bfill for backwars fill 
df3['ExitDate'] =df3['ExitDate'].bfill()#for backward fill

# %%
df3['TerminationDescription'] =df3['TerminationDescription'].ffill() # for forward fill

# %%
df3.isna().sum()
# Out:
# Unnamed: 0                    0
# FirstName                     0
# LastName                      0
# StartDate                     0
# ExitDate                      0
# Title                         0
# Supervisor                    0
# ADEmail                       0
# BusinessUnit                  0
# EmployeeStatus                0
# EmployeeType                  0
# PayZone                       0
# EmployeeClassificationType    0
# TerminationType               0
# TerminationDescription        6
# DepartmentType                0
# Division                      0
# DOB                           0
# State                         0
# JobFunctionDescription        0
# GenderCode                    0
# LocationCode                  0
# RaceDesc                      0
# MaritalDesc                   0
# Performance Score             0
# Current Employee Rating       0
# Employee ID                   0
# Survey Date                   0
# Engagement Score              0
# ...

# %%
mean = df3['Training Duration(Days)'].mean()

# %%
df3['Training Duration(Days)'].fillna(mean) # fill the misiing value by using the mean of its value
# Out:
# 0       2
# 1       4
# 2       2
# 3       3
# 4       5
#        ..
# 3145    1
# 3146    2
# 3147    1
# 3148    4
# 3149    2
# Name: Training Duration(Days), Length: 3150, dtype: int64

# %%
df3.isna().sum()
# Out:
# Unnamed: 0                    0
# FirstName                     0
# LastName                      0
# StartDate                     0
# ExitDate                      0
# Title                         0
# Supervisor                    0
# ADEmail                       0
# BusinessUnit                  0
# EmployeeStatus                0
# EmployeeType                  0
# PayZone                       0
# EmployeeClassificationType    0
# TerminationType               0
# TerminationDescription        6
# DepartmentType                0
# Division                      0
# DOB                           0
# State                         0
# JobFunctionDescription        0
# GenderCode                    0
# LocationCode                  0
# RaceDesc                      0
# MaritalDesc                   0
# Performance Score             0
# Current Employee Rating       0
# Employee ID                   0
# Survey Date                   0
# Engagement Score              0
# ...

# %%
df3.dropna(subset= ['DOB','GenderCode'],inplace = True)

# %%
df3.isna().sum()
# Out:
# Unnamed: 0                    0
# FirstName                     0
# LastName                      0
# StartDate                     0
# ExitDate                      0
# Title                         0
# Supervisor                    0
# ADEmail                       0
# BusinessUnit                  0
# EmployeeStatus                0
# EmployeeType                  0
# PayZone                       0
# EmployeeClassificationType    0
# TerminationType               0
# TerminationDescription        6
# DepartmentType                0
# Division                      0
# DOB                           0
# State                         0
# JobFunctionDescription        0
# GenderCode                    0
# LocationCode                  0
# RaceDesc                      0
# MaritalDesc                   0
# Performance Score             0
# Current Employee Rating       0
# Employee ID                   0
# Survey Date                   0
# Engagement Score              0
# ...
